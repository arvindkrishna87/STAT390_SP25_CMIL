# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import OrderedDict
from datetime import datetime
from PIL import Image
import seaborn as sns
import shutil
import re
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import datasets, transforms, models
from collections import OrderedDict
from datetime import datetime
from PIL import Image
from tqdm import tqdm
from skimage import color, io

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
from PIL import Image

# Increase the maximum allowed image pixels
Image.MAX_IMAGE_PIXELS = None

# %%
case_to_check = 38
patch_dir = '/Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27'

found = False
for root, _, files in os.walk(patch_dir):
    for fname in files:
        match = re.search(r"case_0*(\d+)", fname)
        if match and int(match.group(1)) == case_to_check:
            print(f"Found file: {os.path.join(root, fname)}")
            found = True

if not found:
    print(f"No patches found for case {case_to_check}")
# Out:
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch18.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_h&e_patch41.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_h&e_patch44.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch24.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch30.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch235.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch218.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch221.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch224.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch21.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch209.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_sox10_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch22.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_h&e_patch3.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch230.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch35.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_sox10_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_sox10_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch34.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch20.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch12.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch95.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch53.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch47.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch81.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch11.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch31.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch17.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch25.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch208.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch60.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch56.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch48.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch220.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch17.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch90.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch84.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch42.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch234.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch18.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch11.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch180.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch194.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch191.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_melan_patch22.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match15_h&e_patch18.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch185.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch39.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch12.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch143.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch157.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch27.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_sox10_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch28.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch21.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch152.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch146.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_sox10_patch3.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_melan_patch0.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch108.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch127.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch133.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch195.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch99.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch181.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch66.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch72.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch29.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch34.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch156.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch3.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch142.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch20.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch0.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch143.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch2.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch1.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch21.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch35.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch157.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch73.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch28.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch67.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch180.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch98.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch194.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch132.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch126.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch109.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_sox10_patch2.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch147.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_melan_patch1.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_sox10_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch26.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch153.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch20.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch29.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch156.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch13.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch142.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch184.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch38.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match15_h&e_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_melan_patch23.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch190.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch195.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch10.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch181.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch85.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch235.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch18.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch43.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch49.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch221.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch57.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch91.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch16.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch209.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch61.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch24.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch30.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch10.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch16.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch46.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch80.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch94.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch13.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch52.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch21.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_sox10_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch35.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_sox10_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch34.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch231.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_h&e_patch2.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch23.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch208.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch20.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch225.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch220.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch219.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch234.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch31.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch25.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_h&e_patch45.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_h&e_patch40.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_h&e_patch42.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch33.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch27.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch222.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch236.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_melan_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_h&e_patch0.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch21.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch36.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch233.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch22.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch227.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_sox10_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch78.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch23.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch37.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_sox10_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch82.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch44.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch50.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch11.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch96.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch26.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch63.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch12.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch69.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch32.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch41.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch237.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch87.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch28.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch93.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch55.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch223.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch197.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_melan_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch183.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch12.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch186.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch192.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_melan_patch21.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match15_h&e_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch154.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch179.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch140.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch17.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch11.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch18.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch39.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_melan_patch3.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch30.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch145.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch168.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_sox10_patch0.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch22.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_melan_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch151.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch24.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch130.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch124.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch182.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch196.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch118.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch71.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch169.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch65.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch16.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch23.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch3.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch0.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch141.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch59.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch155.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch154.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch58.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch36.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch2.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch22.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch17.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch140.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch1.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch64.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch168.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch70.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch197.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch119.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch183.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch125.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch131.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch150.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_melan_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch23.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch25.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_melan_patch2.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch38.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_sox10_patch1.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch169.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch144.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch16.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch141.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch10.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match15_h&e_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch178.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch155.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_melan_patch20.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch193.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch187.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch182.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_melan_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch13.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch196.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch92.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch29.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch222.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch54.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch236.png
# ...
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch22.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_sox10_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_melan_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch173.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch24.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_sox10_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch110.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch104.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch81.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch103.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch117.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch95.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch199.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch172.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch25.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch10.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch31.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch8.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch166.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch42.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch56.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch57.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch43.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch18.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch30.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch167.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch173.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch11.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch24.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch116.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch198.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch94.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch80.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_h&e_patch102.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch105.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_sox10_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_25_melan_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_sox10_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch111.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_sox10_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch23.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch25.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch172.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_melan_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch31.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch166.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_sox10_patch37.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_sox10_patch16.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch163.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch10.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_sox10_patch19.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_sox10_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch177.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match15_h&e_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch20.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match15_h&e_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch188.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_melan_patch34.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_29_melan_patch15.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_28_melan_patch13.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch199.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch45.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch26.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch89.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_8_h&e_patch32.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_h&e_patch51.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch239.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch14.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch211.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch67.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_9_h&e_patch205.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_sox10_patch28.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch73.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch98.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_22_melan_patch11.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_melan_patch9.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match13_h&e_patch0.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch62.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_melan_patch5.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch76.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_31_sox10_patch6.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch229.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch204.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match14_h&e_patch3.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_sox10_patch4.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_038_match_24_melan_patch7.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch210.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch38.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_sox10_patch238.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_melan_patch10.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch215.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_26_h&e_patch13.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_7_melan_patch201.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch29.png
# Found file: /Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27/case_38_match_1_sox10_patch15.png

# %%
# === Step 1: Load and clean labels ===
labels = pd.read_csv('/Users/jojokim/Desktop/CMIL/case_grade_match.csv')
labels = labels.drop(index=64, errors='ignore').reset_index(drop=True)

# === Step 2: Group patches by case number ===
def group_patches(patch_dir):
    case_patches = {}
    for filename in os.listdir(patch_dir):
        match = re.search(r"case_(\d+)", filename)
        if match:
            case_num = int(match.group(1))
            case_patches.setdefault(case_num, []).append(os.path.join(patch_dir, filename))
    return case_patches

# === Step 3: Define Dataset class ===
class PNGDataset(Dataset):
    def __init__(self, case_patches, labels_df, transform=None):
        self.case_patches = case_patches
        self.labels_df = labels_df
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for case_num, paths in case_patches.items():
            label_row = labels_df[labels_df['Case'] == case_num]
            if not label_row.empty:
                label = label_row['BinaryClass'].values[0]
                for patch_path in paths:
                    self.image_paths.append(patch_path)
                    self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert('RGB')
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# === Step 4: Transforms ===
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# === Step 5: Load patches and filter labels ===
image_folder_path = '/Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27'
patches = group_patches(image_folder_path)

# Filter for only the "good" cases
good_benign_cases = [2, 21, 22, 25, 34, 45, 53, 77, 78, 79, 85, 90]
good_high_grade_cases = [1, 3, 9, 12, 38, 49, 55, 60, 62, 70, 89, 92, 98, 99]
good_cases = set(good_benign_cases + good_high_grade_cases)

labels = labels[labels['Case'].isin(good_cases) & labels['Class'].isin([1.0, 3.0, 4.0])].copy()
labels['BinaryClass'] = labels['Class'].map({1.0: 0, 3.0: 1, 4.0: 1})

# Filter patch dictionary to good cases
patches = {case: paths for case, paths in patches.items() if case in good_cases}

case_classes = labels.drop_duplicates('Case').set_index('Case')['BinaryClass'].to_dict()
patch_counts = {case: len(patches[case]) for case in patches if case in case_classes}

# === Step 6: Split into train/val/test with class balance ===
from random import seed, shuffle
from sklearn.model_selection import train_test_split
from collections import Counter
import matplotlib.pyplot as plt

seed(42)

# Split cases by class
benign_cases = [c for c in good_benign_cases if c in patch_counts]
high_grade_cases = [c for c in good_high_grade_cases if c in patch_counts]

shuffle(benign_cases)
shuffle(high_grade_cases)

# Choose balanced splits: 60% train, 20% val, 20% test
def split_cases(case_list):
    n = len(case_list)
    n_train = int(0.6 * n)
    n_val = int(0.2 * n)
    return (
        case_list[:n_train],
        case_list[n_train:n_train + n_val],
        case_list[n_train + n_val:]
    )

train_benign, val_benign, test_benign = split_cases(benign_cases)
train_high, val_high, test_high = split_cases(high_grade_cases)

train_cases = train_benign + train_high
val_cases = val_benign + val_high
test_cases = test_benign + test_high

# === Step 7: Match patches to splits ===
train_patches = {c: patches[c] for c in train_cases}
val_patches = {c: patches[c] for c in val_cases}
test_patches = {c: patches[c] for c in test_cases}

# === Step 8: Create datasets and loaders ===
train_dataset = PNGDataset(train_patches, labels, transform=train_transform)
val_dataset = PNGDataset(val_patches, labels, transform=eval_transform)
test_dataset = PNGDataset(test_patches, labels, transform=eval_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# === Step 9: Visualize sample images ===
images, labels_batch = next(iter(train_loader))
fig, axes = plt.subplots(figsize=(10, 4), ncols=5)
for i in range(5):
    axes[i].imshow(images[i].permute(1, 2, 0))
    axes[i].set_title('Benign' if labels_batch[i] == 0 else 'High-grade CMIL')
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# === Step 10: Print class distribution per split ===
def print_loader_stats(name, dataset):
    counts = Counter(dataset.labels)
    print(f"\n{name} Set: Total Patches = {len(dataset)}")
    print(f"  Benign (0):      {counts.get(0, 0)}")
    print(f"  High-grade (1):  {counts.get(1, 0)}")

print_loader_stats("Train", train_dataset)
print_loader_stats("Validation", val_dataset)
print_loader_stats("Test", test_dataset)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.535425].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.4482791].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.4134207].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.3611329].
# Train Set: Total Patches = 6961
#   Benign (0):      2761
#   High-grade (1):  4200
#
# Validation Set: Total Patches = 2180
#   Benign (0):      1157
#   High-grade (1):  1023
#
# Test Set: Total Patches = 3124
#   Benign (0):      817
#   High-grade (1):  2307

# %%
""" # Step 1: Define case lists
benign_cases = [2, 21, 22, 25, 34, 45, 53, 77, 78, 79, 85, 90]
high_grade_cases = [1, 3, 9, 12, 38, 49, 55, 60, 62, 70, 89, 92, 98, 99]
selected_cases = benign_cases + high_grade_cases

# Step 2: Load and clean labels
labels = pd.read_csv('/Users/jojokim/Desktop/CMIL/case_grade_match.csv')
labels = labels.drop(index=64, errors='ignore').reset_index(drop=True)


# Step 3: Group patches by case number
def group_patches(patch_dir):
    case_patches = {}
    for filename in os.listdir(patch_dir):
        match = re.search(r"case_(\d+)", filename)
        if match:
            case_num = int(match.group(1))
            if case_num in selected_cases:
                case_patches.setdefault(case_num, []).append(os.path.join(patch_dir, filename))
    return case_patches

# Load filtered patches
image_folder_path = '/Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27'
patches = group_patches(image_folder_path)

# Check patch availability for high-grade cases
print("\nChecking patch availability for high-grade cases:")
for case in high_grade_cases:
    if case not in patches:
        print(f"Case {case}: NO PATCHES FOUND")
    else:
        
        print(f"Case {case}: {len(patches[case])} patches")
# Check patch availability for high-grade cases
print("\nChecking patch availability for benigh cases:")
for case in benign_cases:
    if case not in patches:
        print(f"Case {case}: NO PATCHES FOUND")
    else:
        print(f"Case {case}: {len(patches[case])} patches")
        
# Step 3.5: Count patches per case
benign_patch_counts = {case: len(patches[case]) for case in benign_cases if case in patches}
high_grade_patch_counts = {case: len(patches[case]) for case in high_grade_cases if case in patches}

# Step 3.6: Sort by patch count (descending) and pick until approximate balance
benign_sorted = sorted(benign_patch_counts.items(), key=lambda x: -x[1])
high_grade_sorted = sorted(high_grade_patch_counts.items(), key=lambda x: -x[1])

selected_benign = []
selected_high_grade = []
benign_total = 0
high_grade_total = 0

i, j = 0, 0
while i < len(benign_sorted) and j < len(high_grade_sorted):
    if benign_total <= high_grade_total:
        case, count = benign_sorted[i]
        selected_benign.append(case)
        benign_total += count
        i += 1
    else:
        case, count = high_grade_sorted[j]
        selected_high_grade.append(case)
        high_grade_total += count
        j += 1

# Combine selected cases
selected_cases = selected_benign + selected_high_grade
print(f"\nSelected benign cases: {selected_benign}")
print(f"Selected high-grade cases: {selected_high_grade}")
print(f"Approximate total patches - Benign: {benign_total}, High-grade: {high_grade_total}")

# Step 4: Filter labels to selected and valid cases
filtered_labels = labels[labels['Case'].isin(selected_cases)].reset_index(drop=True)
filtered_labels = filtered_labels[filtered_labels['Class'].isin([1.0, 3.0, 4.0])].copy()

filtered_labels['BinaryClass'] = filtered_labels['Class'].map({
    1.0: 0,  # Benign
    3.0: 1,  # High-grade (if still present)
    4.0: 1   # High-grade
})

# Step 5: Stratified train/val/test split
X = filtered_labels['Case']
y = filtered_labels['BinaryClass']

train_X, test_X, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=40)
train_X, val_X, y_train, y_val = train_test_split(train_X, y_train, test_size=0.2, stratify=y_train, random_state=40)


# Step 6: Match patch files to splits
train_patches = {int(case): patches[int(case)] for case in train_X if int(case) in patches}
val_patches = {int(case): patches[int(case)] for case in val_X if int(case) in patches}
test_patches = {int(case): patches[int(case)] for case in test_X if int(case) in patches}

# Step 7: Dataset class
class PNGDataset(Dataset):
    def __init__(self, case_patches, labels_df, transform=None):
        self.case_patches = case_patches
        self.labels_df = labels_df
        self.transform = transform
        self.image_paths = []
        self.labels = []

        
        for case_num, patches in case_patches.items():
            label_row = labels_df[labels_df['Case'] == case_num]
            if not label_row.empty:
                binary_label = label_row['BinaryClass'].values[0]
            for patch_path in patches:
                self.image_paths.append(patch_path)
                self.labels.append(binary_label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert('RGB')
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Step 8: Transforms
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Step 9: Create datasets and loaders
train_dataset = PNGDataset(train_patches, filtered_labels, transform=train_transform)
val_dataset = PNGDataset(val_patches, filtered_labels, transform=eval_transform)
test_dataset = PNGDataset(test_patches, filtered_labels, transform=eval_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Step 10: Visualize sample images
images, labels_batch = next(iter(train_loader))
fig, axes = plt.subplots(figsize=(10, 4), ncols=5)
for i in range(5):
    axes[i].imshow(images[i].permute(1, 2, 0))
    axes[i].set_title('Benign' if labels_batch[i] == 0 else 'High-grade CMIL')
    axes[i].axis('off')
plt.tight_layout()
plt.show() """
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/48/ntxvlpl56156qf7xzkxpwlcr0000gn/T/ipykernel_25107/3562839151.py:1: SyntaxWarning: invalid escape sequence '\d'
#   """ # Step 1: Define case lists
# ' # Step 1: Define case lists\nbenign_cases = [2, 21, 22, 25, 34, 45, 53, 77, 78, 79, 85, 90]\nhigh_grade_cases = [1, 3, 9, 12, 38, 49, 55, 60, 62, 70, 89, 92, 98, 99]\nselected_cases = benign_cases + high_grade_cases\n\n# Step 2: Load and clean labels\nlabels = pd.read_csv(\'/Users/jojokim/Desktop/CMIL/case_grade_match.csv\')\nlabels = labels.drop(index=64, errors=\'ignore\').reset_index(drop=True)\n\n\n# Step 3: Group patches by case number\ndef group_patches(patch_dir):\n    case_patches = {}\n    for filename in os.listdir(patch_dir):\n        match = re.search(r"case_(\\d+)", filename)\n        if match:\n            case_num = int(match.group(1))\n            if case_num in selected_cases:\n                case_patches.setdefault(case_num, []).append(os.path.join(patch_dir, filename))\n    return case_patches\n\n# Load filtered patches\nimage_folder_path = \'/Users/jojokim/Library/CloudStorage/GoogleDrive-jojokim2026@u.northwestern.edu/My Drive/CMIL_SP2025_Patches_Apr27\'\npatches = group_patches(image_folder_path)\n\n# Check patch availability for high-grade cases\nprint("\nChecking patch availability for high-grade cases:")\nfor case in high_grade_cases:\n    if case not in patches:\n        print(f"Case {case}: NO PATCHES FOUND")\n    else:\n        \n        print(f"Case {case}: {len(patches[case])} patches")\n# Check patch availability for high-grade cases\nprint("\nChecking patch availability for benigh cases:")\nfor case in benign_cases:\n    if case not in patches:\n        print(f"Case {case}: NO PATCHES FOUND")\n    else:\n        print(f"Case {case}: {len(patches[case])} patches")\n        \n# Step 3.5: Count patches per case\nbenign_patch_counts = {case: len(patches[case]) for case in benign_cases if case in patches}\nhigh_grade_patch_counts = {case: len(patches[case]) for case in high_grade_cases if case in patches}\n\n# Step 3.6: Sort by patch count (descending) and pick until approximate balance\nbenign_sorted = sorted(benign_patch_counts.items(), key=lambda x: -x[1])\nhigh_grade_sorted = sorted(high_grade_patch_counts.items(), key=lambda x: -x[1])\n\nselected_benign = []\nselected_high_grade = []\nbenign_total = 0\nhigh_grade_total = 0\n\ni, j = 0, 0\nwhile i < len(benign_sorted) and j < len(high_grade_sorted):\n    if benign_total <= high_grade_total:\n        case, count = benign_sorted[i]\n        selected_benign.append(case)\n        benign_total += count\n        i += 1\n    else:\n        case, count = high_grade_sorted[j]\n        selected_high_grade.append(case)\n        high_grade_total += count\n        j += 1\n\n# Combine selected cases\nselected_cases = selected_benign + selected_high_grade\nprint(f"\nSelected benign cases: {selected_benign}")\nprint(f"Selected high-grade cases: {selected_high_grade}")\nprint(f"Approximate total patches - Benign: {benign_total}, High-grade: {high_grade_total}")\n\n# Step 4: Filter labels to selected and valid cases\nfiltered_labels = labels[labels[\'Case\'].isin(selected_cases)].reset_index(drop=True)\nfiltered_labels = filtered_labels[filtered_labels[\'Class\'].isin([1.0, 3.0, 4.0])].copy()\n\nfiltered_labels[\'BinaryClass\'] = filtered_labels[\'Class\'].map({\n    1.0: 0,  # Benign\n    3.0: 1,  # High-grade (if still present)\n    4.0: 1   # High-grade\n})\n\n# Step 5: Stratified train/val/test split\nX = filtered_labels[\'Case\']\ny = filtered_labels[\'BinaryClass\']\n\ntrain_X, test_X, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=40)\ntrain_X, val_X, y_train, y_val = train_test_split(train_X, y_train, test_size=0.2, stratify=y_train, random_state=40)\n\n\n# Step 6: Match patch files to splits\ntrain_patches = {int(case): patches[int(case)] for case in train_X if int(case) in patches}\nval_patches = {int(case): patches[int(case)] for case in val_X if int(case) in patches}\ntest_patches = {int(case): patches[int(case)] for case in test_X if int(case) in patches}\n\n# Step 7: Dataset class\nclass PNGDataset(Dataset):\n     ...

# %%
# Define validation loss and accuracy

""" def validation(model, criterion, val_loade, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.eval()
    val_loss = 0
    accuracy = 0

    for images, labels in iter(val_loader):
        output = model.forward(images)
        val_loss += criterion(output, labels).item()

        probabilities = torch.exp(output)

        equality = labels.data == probabilities.max(dim=1)[1]
        accuracy += equality.type(torch.FloatTensor).mean()

    return val_loss, accuracy """
# Out:
# " def validation(model, criterion, val_loade, device='cuda' if torch.cuda.is_available() else 'cpu'):\n    model.eval()\n    val_loss = 0\n    accuracy = 0\n\n    for images, labels in iter(val_loader):\n        output = model.forward(images)\n        val_loss += criterion(output, labels).item()\n\n        probabilities = torch.exp(output)\n\n        equality = labels.data == probabilities.max(dim=1)[1]\n        accuracy += equality.type(torch.FloatTensor).mean()\n\n    return val_loss, accuracy "

# %%
import os
import torch
from tqdm import tqdm
import matplotlib.pyplot as plt

def train_model(model, optimizer, criterion, train_loader, val_loader, epochs=3,
                scheduler=None, resume_from=None, device='cuda' if torch.cuda.is_available() else 'cpu',
                pool_size=(1, 1)):

    train_losses = []
    val_losses = []
    val_accuracies = []

    model_dir = "./models_5_14"
    os.makedirs(model_dir, exist_ok=True)

    model.to(device)
    best_acc = 0
    start_epoch = 0

    # Resume from checkpoint if specified
    if resume_from is not None and os.path.exists(resume_from):
        checkpoint = torch.load(resume_from, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch']
        best_acc = checkpoint.get('val_accuracy', 0)
        print(f"🔁 Resumed from checkpoint at epoch {start_epoch} with accuracy {best_acc:.4f}")

    for e in range(start_epoch, epochs):
        model.train()
        running_loss = 0

        train_bar = tqdm(train_loader, desc=f"Epoch {e+1}/{epochs}", leave=True)
        for images, labels in train_bar:
            images = [img.to(device) for img in images]
            labels = labels.to(device)
            images = torch.stack(images)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            train_bar.set_postfix(loss=running_loss / (train_bar.n + 1))

        epoch_train_loss = running_loss / len(train_loader)

        # Step the learning rate scheduler if present
        if scheduler:
            scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            validation_loss = 0
            correct = 0
            total = 0

            for images, labels in val_loader:
                images = [img.to(device) for img in images]
                labels = labels.to(device)
                images = torch.stack(images)

                outputs = model(images)
                loss = criterion(outputs, labels)
                validation_loss += loss.item()

                preds = outputs.argmax(dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)

            avg_val_loss = validation_loss / len(val_loader)
            val_accuracy = correct / total

        print(
            f"Epoch: {e+1}/{epochs}.. "
            f"Train Loss: {epoch_train_loss:.3f}.. "
            f"Val Loss: {avg_val_loss:.3f}.. "
            f"Val Accuracy: {val_accuracy:.3f}"
        )

        # Save checkpoint
        torch.save({
            'epoch': e + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': epoch_train_loss,
            'val_loss': avg_val_loss,
            'val_accuracy': val_accuracy
        }, os.path.join(model_dir, f"model_epoch_{e+1}.pth"))

        if val_accuracy > best_acc:
            best_acc = val_accuracy
            torch.save(model.state_dict(), os.path.join(model_dir, "best_model.pth"))
            print(f"✅ New best model saved at epoch {e+1} with accuracy {val_accuracy:.4f}")

        train_losses.append(epoch_train_loss)
        val_losses.append(avg_val_loss)
        val_accuracies.append(val_accuracy)

    # Plotting
    epochs_range = range(1, epochs + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_losses, label='Training Loss')
    plt.plot(epochs_range, val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss During Training')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, val_accuracies, label='Validation Accuracy', color='green')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Validation Accuracy During Training')
    plt.legend()

    plt.tight_layout()
    plt.show()

    return model

# %%
def save_checkpoint(model, class_mapping, arch):
    """
    Save trained model weights.

    Input:
    arch(str): Model architecture
    """

    checkpoint = {
        "arch": arch,
        "class_to_idx": class_mapping,
        "model_state_dict": model.state_dict(),
    }

    timestamp = datetime.now().date().strftime("%Y%m%d")
    torch.save(checkpoint, f"../checkpoint/{timestamp}_{arch}.pth")

# %%
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
        self.fc1 = nn.Conv2d(in_planes, in_planes // ratio, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Conv2d(in_planes // ratio, in_planes, 1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        return self.sigmoid(avg_out + max_out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        padding = 3 if kernel_size == 7 else 1
        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        return self.sigmoid(self.conv1(x))

class CBAM(nn.Module):
    def __init__(self, channels):
        super(CBAM, self).__init__()
        self.ca = ChannelAttention(channels)
        self.sa = SpatialAttention()

    def forward(self, x):
        x = self.ca(x) * x
        x = self.sa(x) * x
        return x

# ----------------- RESNET50 WITH CBAM ----------------- #
class ResNetCBAM(nn.Module):
    def __init__(self, num_classes=2, adaptive_pool_size=(1, 1)):
        super(ResNetCBAM, self).__init__()
        base = models.resnet50(pretrained=True)
        self.features = nn.Sequential(
            base.conv1,
            base.bn1,
            base.relu,
            base.maxpool,
            base.layer1,
            CBAM(256),
            base.layer2,
            CBAM(512),
            base.layer3,
            CBAM(1024),
            base.layer4,
            CBAM(2048),
        )
        self.avgpool = nn.AdaptiveAvgPool2d(output_size=adaptive_pool_size)
        self.fc = nn.Linear(2048 * adaptive_pool_size[0] * adaptive_pool_size[1], num_classes)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        return self.fc(x)

# set adaptive pooling window
pool_size = (1, 1)

# Instantiate model
model = ResNetCBAM(num_classes=2, adaptive_pool_size=pool_size)

""" # Optimizer and Loss
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4) """
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ' # Optimizer and Loss\ncriterion = nn.CrossEntropyLoss()\noptimizer = optim.Adam(model.parameters(), lr=1e-4) '

# %%
# Loss function: CrossEntropyLoss (expects raw logits)
criterion = nn.CrossEntropyLoss()

# Optimizer: only update the final fully connected layer (fc)
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %%
""" # Train model
resnet_model = train_model(model, optimizer, criterion, train_loader, val_loader) """
# Out:
# ' # Train model\nresnet_model = train_model(model, optimizer, criterion, train_loader, val_loader) '

# %%
""" resnet_model = train_model(
    model=model,
    optimizer=optimizer,
    criterion=criterion,
    train_loader=train_loader,
    val_loader=val_loader,
    epochs=5,  # total number of epochs to reach
    resume_from='./models_5_14/model_epoch_3.pth')  # path to last checkpoint """
# Out:
# " resnet_model = train_model(\n    model=model,\n    optimizer=optimizer,\n    criterion=criterion,\n    train_loader=train_loader,\n    val_loader=val_loader,\n    epochs=5,  # total number of epochs to reach\n    resume_from='./models_5_14/model_epoch_3.pth')  # path to last checkpoint "

# %%
import torch
import os
import itertools

def grid_search_pool_size(model_class, optimizer, criterion, train_loader, val_loader, epochs=3,
                          pool_sizes=[(1, 1), (2, 2), (4, 4)], device='cuda' if torch.cuda.is_available() else 'cpu'):
    best_acc = 0
    best_pool_size = None
    best_model = None

    # Define a directory to save models
    model_dir = "./models_5_14_grid_search"
    os.makedirs(model_dir, exist_ok=True)

    # Iterate over all pool sizes
    for pool_size in pool_sizes:
        print(f"Training with pool size: {pool_size}")

        # Instantiate a new model for each trial
        model = model_class(num_classes=2, adaptive_pool_size=pool_size).to(device)
        
        # Reset optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        
        # Train the model
        model_trained = train_model(model, optimizer, criterion, train_loader, val_loader, epochs=epochs, 
                                    pool_size=pool_size, device=device)

        # Evaluate model performance
        model_trained.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images = [img.to(device) for img in images]
                labels = labels.to(device)
                images = torch.stack(images)
                outputs = model_trained(images)
                preds = outputs.argmax(dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)
                
        val_accuracy = correct / total
        print(f"Validation Accuracy for pool size {pool_size}: {val_accuracy:.4f}")


        # Save current model's weights with pool size in filename
        pool_str = f"{pool_size[0]}x{pool_size[1]}"
        save_path = os.path.join(model_dir, f"model_pool_{pool_str}.pth")
        torch.save(model_trained.state_dict(), save_path)
        
        # Track the best pool size based on validation accuracy
        if val_accuracy > best_acc:
            best_acc = val_accuracy
            best_pool_size = pool_size
            best_model = model_trained.state_dict()

    print(f"Best Pool Size: {best_pool_size} with accuracy: {best_acc:.4f}")

    # Save the best model
    torch.save(best_model, os.path.join(model_dir, "best_model.pth"))
    
    return best_pool_size, best_acc

# %%
# Define the optimizer and criterion as per your setup
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

# Run grid search
best_pool_size, best_accuracy = grid_search_pool_size(ResNetCBAM, optimizer, criterion, train_loader, val_loader, epochs=5, pool_sizes=[(1, 1), (2, 2), (3, 3), (4, 4)], device='cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Training with pool size: (1, 1)
# Epoch 1/5: 100%|██████████| 218/218 [26:53<00:00,  7.40s/it, loss=0.347]
# Epoch: 1/5.. Train Loss: 0.347.. Val Loss: 0.930.. Val Accuracy: 0.750
# ✅ New best model saved at epoch 1 with accuracy 0.7495
# Epoch 2/5: 100%|██████████| 218/218 [21:32<00:00,  5.93s/it, loss=0.228]
# Epoch: 2/5.. Train Loss: 0.228.. Val Loss: 1.073.. Val Accuracy: 0.684
# Epoch 3/5: 100%|██████████| 218/218 [21:02<00:00,  5.79s/it, loss=0.204]
# Epoch: 3/5.. Train Loss: 0.204.. Val Loss: 1.501.. Val Accuracy: 0.692
# Epoch 4/5: 100%|██████████| 218/218 [16:00<00:00,  4.40s/it, loss=0.182]
# Epoch: 4/5.. Train Loss: 0.182.. Val Loss: 1.406.. Val Accuracy: 0.659
# Epoch 5/5: 100%|██████████| 218/218 [15:59<00:00,  4.40s/it, loss=0.158]
# Epoch: 5/5.. Train Loss: 0.158.. Val Loss: 1.457.. Val Accuracy: 0.651
# Validation Accuracy for pool size (1, 1): 0.6514
# Training with pool size: (2, 2)
# Epoch 1/5: 100%|██████████| 218/218 [16:00<00:00,  4.41s/it, loss=0.346]
# Epoch: 1/5.. Train Loss: 0.346.. Val Loss: 0.962.. Val Accuracy: 0.718
# ✅ New best model saved at epoch 1 with accuracy 0.7183
# Epoch 2/5: 100%|██████████| 218/218 [16:03<00:00,  4.42s/it, loss=0.239]
# Epoch: 2/5.. Train Loss: 0.239.. Val Loss: 1.081.. Val Accuracy: 0.693
# Epoch 3/5: 100%|██████████| 218/218 [16:02<00:00,  4.41s/it, loss=0.198]
# Epoch: 3/5.. Train Loss: 0.198.. Val Loss: 1.920.. Val Accuracy: 0.548
# Epoch 4/5: 100%|██████████| 218/218 [16:05<00:00,  4.43s/it, loss=0.177]
# Epoch: 4/5.. Train Loss: 0.177.. Val Loss: 1.289.. Val Accuracy: 0.614
# Epoch 5/5: 100%|██████████| 218/218 [16:03<00:00,  4.42s/it, loss=0.162]
# Epoch: 5/5.. Train Loss: 0.162.. Val Loss: 0.892.. Val Accuracy: 0.704
# Validation Accuracy for pool size (2, 2): 0.7037
# Training with pool size: (3, 3)
# Epoch 1/5: 100%|██████████| 218/218 [16:03<00:00,  4.42s/it, loss=0.397]
# Epoch: 1/5.. Train Loss: 0.397.. Val Loss: 1.093.. Val Accuracy: 0.660
# ✅ New best model saved at epoch 1 with accuracy 0.6596
# Epoch 2/5: 100%|██████████| 218/218 [16:01<00:00,  4.41s/it, loss=0.27]
# Epoch: 2/5.. Train Loss: 0.270.. Val Loss: 1.335.. Val Accuracy: 0.650
# Epoch 3/5: 100%|██████████| 218/218 [15:58<00:00,  4.40s/it, loss=0.215]
# Epoch: 3/5.. Train Loss: 0.215.. Val Loss: 1.036.. Val Accuracy: 0.682
# ✅ New best model saved at epoch 3 with accuracy 0.6821
# Epoch 4/5: 100%|██████████| 218/218 [15:54<00:00,  4.38s/it, loss=0.205]
# Epoch: 4/5.. Train Loss: 0.205.. Val Loss: 1.223.. Val Accuracy: 0.705
# ✅ New best model saved at epoch 4 with accuracy 0.7046
# Epoch 5/5: 100%|██████████| 218/218 [15:56<00:00,  4.39s/it, loss=0.173]
# Epoch: 5/5.. Train Loss: 0.173.. Val Loss: 1.514.. Val Accuracy: 0.652
# Validation Accuracy for pool size (3, 3): 0.6523
# Training with pool size: (4, 4)
# Epoch 1/5: 100%|██████████| 218/218 [15:56<00:00,  4.39s/it, loss=0.375]
# Epoch: 1/5.. Train Loss: 0.375.. Val Loss: 0.838.. Val Accuracy: 0.738
# ✅ New best model saved at epoch 1 with accuracy 0.7381
# Epoch 2/5: 100%|██████████| 218/218 [15:58<00:00,  4.40s/it, loss=0.232]
# Epoch: 2/5.. Train Loss: 0.232.. Val Loss: 0.831.. Val Accuracy: 0.661
# Epoch 3/5: 100%|██████████| 218/218 [15:55<00:00,  4.39s/it, loss=0.205]
# Epoch: 3/5.. Train Loss: 0.205.. Val Loss: 1.274.. Val Accuracy: 0.674
# Epoch 4/5: 100%|██████████| 218/218 [16:05<00:00,  4.43s/it, loss=0.178]
# Epoch: 4/5.. Train Loss: 0.178.. Val Loss: 2.424.. Val Accuracy: 0.540
# Epoch 5/5: 100%|██████████| 218/218 [16:24<00:00,  4.52s/it, loss=0.147]
# Epoch: 5/5.. Train Loss: 0.147.. Val Loss: 1.756.. Val Accuracy: 0.658
# Validation Accuracy for pool size (4, 4): 0.6583
# Best Pool Size: (2, 2) with accuracy: 0.7037

# %%
# Instantiate and load
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ResNetCBAM(num_classes=2, adaptive_pool_size=best_pool_size).to(device)

# Load trained weights
model.load_state_dict(torch.load('/Users/jojokim/Documents/GitHub/STAT390_SP25_CMIL/ML/Jojo/models_5_14_grid_search/best_model.pth', map_location=device))
model.eval()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNetCBAM(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): CBAM(
#       (ca): ChannelAttention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (max_pool): AdaptiveMaxPool2d(output_size=1)
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (relu1): ReLU()
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (sigmoid): Sigmoid()
#       )
#       (sa): SpatialAttention(
#         (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#         (sigmoid): Sigmoid()
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): CBAM(
#       (ca): ChannelAttention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (max_pool): AdaptiveMaxPool2d(output_size=1)
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (relu1): ReLU()
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (sigmoid): Sigmoid()
#       )
#       (sa): SpatialAttention(
#         (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#         (sigmoid): Sigmoid()
#       )
#     )
#     (8): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (9): CBAM(
#       (ca): ChannelAttention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (max_pool): AdaptiveMaxPool2d(output_size=1)
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (relu1): ReLU()
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (sigmoid): Sigmoid()
#       )
#       (sa): SpatialAttention(
#         (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#         (sigmoid): Sigmoid()
#       )
#     )
#     (10): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (11): CBAM(
#       (ca): ChannelAttention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (max_pool): AdaptiveMaxPool2d(output_size=1)
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (relu1): ReLU()
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (sigmoid): Sigmoid()
#       )
#       (sa): SpatialAttention(
#         (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#         (sigmoid): Sigmoid()
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(2, 2))
#   (fc): Linear(in_features=8192, out_features=2, bias=True)
# )

# %%
def get_predictions(model, dataloader, device='cuda' if torch.cuda.is_available() else 'cpu'):
    model.to(device)
    model.eval()
    
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            preds = outputs.argmax(dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    return all_labels, all_preds

# %%
# Get true and predicted labels
true_labels, pred_labels = get_predictions(model, test_loader)  # or val_loader

# %%
# If binary classification, use average='binary'; for multiclass use 'macro' or 'weighted'
precision = precision_score(true_labels, pred_labels, average='binary')
recall = recall_score(true_labels, pred_labels, average='binary')
f1 = f1_score(true_labels, pred_labels, average='binary')
accuracy = accuracy_score(true_labels, pred_labels)

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
# Out:
# Accuracy:  0.2923
# Precision: 0.9068
# Recall:    0.0464
# F1 Score:  0.0882

# %%
cm = confusion_matrix(true_labels, pred_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Benign', 'High-grade CMIL'],
            yticklabels=['Benign', 'High-grade CMIL'])
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
print("\nClassification Report:")
print(classification_report(true_labels, pred_labels, target_names=['Benign', 'Malignant']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       0.27      0.99      0.42       817
#    Malignant       0.91      0.05      0.09      2307
#
#     accuracy                           0.29      3124
#    macro avg       0.59      0.52      0.25      3124
# weighted avg       0.74      0.29      0.18      3124

# %%
import cv2
from torchvision import transforms
from torch.nn import functional as F

class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None
        self._register_hooks()

    def _register_hooks(self):
        def forward_hook(module, input, output):
            self.activations = output.detach()
        def backward_hook(module, grad_input, grad_output):
            self.gradients = grad_output[0].detach()
        self.target_layer.register_forward_hook(forward_hook)
        self.target_layer.register_backward_hook(backward_hook)

    def generate(self, input_tensor, class_idx=None):
        self.model.eval()
        output = self.model(input_tensor)
        if class_idx is None:
            class_idx = output.argmax(dim=1).item()
        loss = output[:, class_idx].sum()
        self.model.zero_grad()
        loss.backward()
        weights = self.gradients.mean(dim=(2, 3), keepdim=True)
        grad_cam_map = (weights * self.activations).sum(dim=1, keepdim=True)
        grad_cam_map = F.relu(grad_cam_map)
        grad_cam_map = F.interpolate(grad_cam_map, size=input_tensor.shape[2:], mode='bilinear', align_corners=False)
        grad_cam_map = grad_cam_map.squeeze().cpu().numpy()
        grad_cam_map -= grad_cam_map.min()
        grad_cam_map /= grad_cam_map.max()
        return grad_cam_map

# Instantiate Grad-CAM using final bottleneck block
target_layer = model.features[10][-1]
cam = GradCAM(model, target_layer)

# Process first 5 patches in test loader
num_images = 5
image_batch, label_batch = next(iter(test_loader))

plt.figure(figsize=(15, 3 * num_images))
for i in range(num_images):
    input_tensor = image_batch[i].unsqueeze(0)
    label = label_batch[i].item()
    pred_class = model(input_tensor).argmax().item()
    
    heatmap = cam.generate(input_tensor)
    
    img = input_tensor.squeeze().permute(1, 2, 0).cpu().numpy()
    img = (img - img.min()) / (img.max() - img.min())
    heatmap_img = cv2.applyColorMap(np.uint8(255 * heatmap), cv2.COLORMAP_JET)
    overlay = cv2.addWeighted(np.uint8(255 * img), 0.6, heatmap_img, 0.4, 0)

    # Extract case number if filename or metadata available
    try:
        filename = test_loader.dataset.image_paths[i]
        case_match = re.search(r"case_(\d+)", filename)
        case_str = f"Case {case_match.group(1)}" if case_match else "Unknown Case"
    except:
        case_str = "Unknown Case"

    # Plot original and overlay
    plt.subplot(num_images, 2, 2*i + 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"{case_str} - Original")

    plt.subplot(num_images, 2, 2*i + 2)
    plt.imshow(overlay[..., ::-1])
    plt.axis('off')
    plt.title(f"{case_str} - Grad-CAM (True: {label}, Pred: {pred_class})")

plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1842: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
